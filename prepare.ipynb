# %%
# !pip install requests numpy zstandard tqdm chess torch

# %%
import numpy as np

from utils import download_lichess_dataset, create_dataset_from_pgn

download_lichess_dataset(2016,1)
dataset = create_dataset_from_pgn(2016,1,1000000)

# %%
np.save('1m_markers_1_1.npy', dataset)
